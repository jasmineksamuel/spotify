# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np
import config as config

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=config.cid, client_secret=config.secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# we will start by searching the top 50 categories in the US on spotify
results = sp.categories(country='US', limit=50)
categories = results['categories']

# create a list of top categories
cat_list = []
for i, j in enumerate(categories['items']):
    cat_list.append(j['id'])

# %%
# We will search for the top playlist in each category 
top_playlists = []
for j, i in enumerate(cat_list):
    top_playlists.append(sp.search(q=i, type='playlist', limit=1))

# %%
# Let's create parse the data to get get the different attributes of each playlist
playlist_description = []
playlist_id = []
playlist_name = []
playlist_total_tracks = []
playlist_tracks = []
playlist_uri = []
for j, i in enumerate(top_playlists):
    try:
        playlist_description.append((i['playlists']['items'][0]['description']))
        playlist_id.append(i['playlists']['items'][0]['id'])
        playlist_name.append(i['playlists']['items'][0]['name'])
        playlist_total_tracks.append(i['playlists']['items'][0]['tracks']['total'])
        playlist_tracks.append(i['playlists']['items'][0]['tracks'])
        playlist_uri.append(i['playlists']['items'][0]['uri'])
    except IndexError:
        pass

# %%
# create df with top_playlists data
'''
Playlist_name(str): The name of the playlist
Playlist_id(int): the unique id of the corresponding playlist 
Playlist_description(str): description of the playlist 
Playlist_total_tracks(int): The total sum of tracks in each playlist reported by spotify
Playlist_uri(str): Unique identifier of the playlist

'''



top_playlists = pd.DataFrame({'Playlist_name':playlist_name, 'Playlist_id':playlist_id, 'Playlist_description':playlist_description,
                              'Total_tracks':playlist_total_tracks, 'Playlist_uri':playlist_uri})

# %%
top_playlists
# Out:
#                               Playlist_name             Playlist_id  \
# 0                   Music Authentic Toplist  2CXMVKT2IuLSeA4Rv7pMxD
# 1                                 RapCaviar  37i9dQZF1DX0XUsuxWHRQd
# 2                             Sangeet Night  37i9dQZF1DX2ktNbDFDPWZ
# 3                                Pop Rising  37i9dQZF1DWUa8ZRTfalHk
# 4                              Country Hits  6nU0t33tQA2i0qTI5HiyRV
# 5                                   Workout  37i9dQZF1DX70RN3TfWWJh
# 6                             Rock Classics  37i9dQZF1DWXRqgorJj26U
# 7                  Songs to Sing in the Car  37i9dQZF1DWWMOmoXKqHTD
# 8                             Latin Hit Mix  37i9dQZF1DXbLMw3ry7d7k
# 9                              Mood Booster  37i9dQZF1DX3rxVfibe1L0
# 10                                 RNB MOOD  2KFz8HGQ2NpaC6uYFTq4Sg
# 11             Contemporary Black Composers  4WqKz9qNKwICVYSfZsQ4gq
# 12                            Gaming Lounge  37i9dQZF1DX9QWEVCu9UDA
# 13                               Focus Flow  37i9dQZF1DWZZbwlv3Vmtr
# 14                       Edm & Dance Music   7jCvrseBwisIEfYOWFS5Vd
# 15                               Chill Hits  37i9dQZF1DX4WYpdgoIcn6
# 16                At Home: Cover Songs 2020  4DjPDmk3r4OUwwzJTafBFJ
# 17  Indie Alternative | Ultimate Indie 2020  6u1Ura1PXLSyavFsnaIiXP
# 18                       Inspirational Walk  37i9dQZF1DX5yf1SQXKtUJ
# 19                             Decades Hits  4RvFgqkdx11Yeke2Wc3bEc
# 20                    Studenten 2021!!!!!!!  7npwN08ckIXYrMyRzfUe2L
# 21                          Alternative 10s  37i9dQZF1DX873GaRGUmPl
# 31  ¡Ponte cursi con las canciones más románticas ...            60
# 32  Score all the hottest hits from your favourite...            50
# 33  Punk rock from the 90s and 00s that you need i...            50
# 34  The new school of Regional Mexican. Los nuevos...            75
# 35  Featuing talented artists that know how to pop...            14
# 36                             Best Songs to Dance on            62
# 37           Desi hits from South Asia and the world.            75
# 38  Best Anime OST, Songs, Music Opening &amp; End...           111
# 39  MISSING SONGS: Fanfare by Thomas Gold; REMIXES...           545
# 40  The biggest Afropop records on the planet.  Co...            50
# 41  Get to know some of the most loved comedians o...           102
# 42  Want some metal? Better to start with the esse...            78
# 43  Solo los clásicos. The movement’s roots. Cover...           100
# 44                   Nothing but classic blues tracks            70
# 45                                      Classic funk.            55
# 46                                                              233
#
#                                Playlist_uri
# 0   spotify:playlist:2CXMVKT2IuLSeA4Rv7pMxD
# 1   spotify:playlist:37i9dQZF1DX0XUsuxWHRQd
# 2   spotify:playlist:37i9dQZF1DX2ktNbDFDPWZ
# 3   spotify:playlist:37i9dQZF1DWUa8ZRTfalHk
# 4   spotify:playlist:6nU0t33tQA2i0qTI5HiyRV
# 5   spotify:playlist:37i9dQZF1DX70RN3TfWWJh
# 6   spotify:playlist:37i9dQZF1DWXRqgorJj26U
# 7   spotify:playlist:37i9dQZF1DWWMOmoXKqHTD
# 8   spotify:playlist:37i9dQZF1DXbLMw3ry7d7k
# 9   spotify:playlist:37i9dQZF1DX3rxVfibe1L0
# 10  spotify:playlist:2KFz8HGQ2NpaC6uYFTq4Sg
# 11  spotify:playlist:4WqKz9qNKwICVYSfZsQ4gq
# 12  spotify:playlist:37i9dQZF1DX9QWEVCu9UDA
# 13  spotify:playlist:37i9dQZF1DWZZbwlv3Vmtr
# 14  spotify:playlist:7jCvrseBwisIEfYOWFS5Vd
# 15  spotify:playlist:37i9dQZF1DX4WYpdgoIcn6
# 16  spotify:playlist:4DjPDmk3r4OUwwzJTafBFJ
# 17  spotify:playlist:6u1Ura1PXLSyavFsnaIiXP
# 18  spotify:playlist:37i9dQZF1DX5yf1SQXKtUJ
# 19  spotify:playlist:4RvFgqkdx11Yeke2Wc3bEc
# 20  spotify:playlist:7npwN08ckIXYrMyRzfUe2L
# 21  spotify:playlist:37i9dQZF1DX873GaRGUmPl
# 22  spotify:playlist:37i9dQZF1DX59HcpGmPXYR
# 23  spotify:playlist:37i9dQZF1DXdgnLr18vPvu
# 24  spotify:playlist:37i9dQZF1DWZd79rJ6a7lp
# 25  spotify:playlist:37i9dQZF1DWWEJlAGA9gs0
# 26  spotify:playlist:37i9dQZF1DX0SM0LYsmbMT
# 27  spotify:playlist:37i9dQZF1DWYV7OOaGhoH0
# 28  spotify:playlist:37i9dQZF1DWULEW2RfoSCi
# 29  spotify:playlist:37i9dQZF1DWY3pbjsJ6MxA
# 30  spotify:playlist:37i9dQZF1DX4xuWVBs4FgJ
# 31  spotify:playlist:37i9dQZF1DX1S3aM8sZo63
# 32  spotify:playlist:37i9dQZF1DX9tPFwDMOaN1
# 33  spotify:playlist:37i9dQZF1DXd6tJtr4qeot
# 34  spotify:playlist:37i9dQZF1DX10A9MXc7csF
# 35  spotify:playlist:6yAd7B2Vrw5kJtfqpuPbtf
# 36  spotify:playlist:0sjIXTb8OgGBi1lEu0UGRC
# 37  spotify:playlist:37i9dQZF1DWTwzVdyRpXm1
# 38  spotify:playlist:1YA5cPIfDy3L03bGnNiDM7
# 39  spotify:playlist:0DMxXTG4lkkDFEnZ9kf0ee
# 40  spotify:playlist:37i9dQZF1DWYs2pvwxWA7l
# 41  spotify:playlist:37i9dQZF1DWSRoT7QRAibZ
# 42  spotify:playlist:37i9dQZF1DWWOaP4H0w5b0
# 43  spotify:playlist:37i9dQZF1DX8SfyqmSFDwe
# 44  spotify:playlist:37i9dQZF1DXd9rSDyQguIk
# 45  spotify:playlist:37i9dQZF1DX6drTZKzZwSo
# 46  spotify:playlist:0yXe2Ok6uWm15lzStDZIyN

# %%
# create a function that will return all playlist tracks
def get_playlist_tracks(playlist_id):
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
# Create a list of all tracks in each playlist using playlist_uri
top_playlist_tracks = []
for i in playlist_uri:
    top_playlist_tracks.append(get_playlist_tracks(i))

# %%
# we'll create an ordered list that corresponds to the track numbers
tracknumber = []
for l in top_playlists['Total_tracks']:
    for k in (range(0,l)):
             tracknumber.append(k)

# %%
# we'll create an ordered list that corresponds to the playlist            
x1 = [n for n,l in enumerate(top_playlists['Total_tracks'])]
indexs = np.repeat(x1,top_playlists['Total_tracks'])
indexs = indexs.tolist()

# %%
# create a tuple of index and tracknumber that will be used to parse the
# json response for each track of each playlist
tracks = zip(indexs,tracknumber)

# %%
track_duration = []
track_name = []
track_id = []
track_artist_name = []
track_popularity = []
artist_id = []
for u,(i,j) in enumerate(tracks):
    try:
        track_duration.append(top_playlist_tracks[i][j]['track']['duration_ms'])
        track_name.append(top_playlist_tracks[i][j]['track']['name'])
        track_id.append(top_playlist_tracks[i][j]['track']['id'])
        track_artist_name.append(top_playlist_tracks[i][j]['track']['artists'][0]['name'])
        track_popularity.append(top_playlist_tracks[i][j]['track']['popularity'])
        artist_id.append(top_playlist_tracks[i][j]['track']['artists'][0]['id'])
    except:
        track_duration.append(f'NULL')
        track_name.append(f'NULL')
        track_id.append(f'NULL')
        track_artist_name.append(f'NULL')
        track_popularity.append(f'NULL')
        artist_id.append(f'NULL')
        print(f'error {u},{i},{j}')
# Out:
# error 5042,46,179
# error 5043,46,180

# %% [markdown]
#  in some instances we see tracks with null data- we'll have to remove this

# %%
# create a list that corresponds to the playlist uri of each track 
x2 = [n for n,l in enumerate(top_playlists['Total_tracks'])]
spotify_playlist = np.repeat(top_playlists['Playlist_uri'],top_playlists['Total_tracks'])
spotify_playlist = spotify_playlist.tolist()

# %%
# create playlist tracks df
'''
track_name(str): name of track
track_artist_name(str): name of the artist that corresponds to the track 
artist_id(str): unique identifier of artist 
track_duration(int): duration of the track in milliseconds
track_id(str): unique identifier of the track 
track_popularity(int): a popularity score spotify assigns to each track 
Playlist_id(str): unique identifier that corresponds to the playlist each track belongs to

'''


Playlist_tracks = pd.DataFrame({'track_name':track_name,'track_artist_name':track_artist_name, 'artist_id':artist_id,
                                'track_duration':track_duration,'track_id':track_id,'track_popularity':track_popularity,
                                                                                        'Playlist_id':spotify_playlist})

# %%
Playlist_tracks.head()
# Out:
#               track_name track_artist_name               artist_id  \
# 0        12 Ways of Love   Neoborn Caveman  0iKRW4b8bfLlzCnd8Xujq4
# 1                   Pray     SUGAR JUNKIES  4o9FJ8F3q3qd6ZbZCoqES3
# 2    Flowers + Champagne           J GRGRY  4c72CNdE5TcIvtO9lcZ8MI
# 3            You Love Me        Danny Kean  1k1ht0y64tgCekqyRTSLxi
# 4  Twelve Weeks Straight         Dan Cross  4Ahvs4zBYtmiTV4h8uncUY
#
#   track_duration                track_id track_popularity  \
# 0         195371  3cuNe36pZVyz5eJ4JDVBVj               42
# 1         216000  1QC3ArMG7s8ZoHQBREetAb               26
# 2         204395  4M7R2zKfyu93RjIbx6FgWK               24
# 3         178730  6R7UkgxJAbc11FjuSdmzNx               22
# 4         300565  5j2fBWjpH2a8oVtiR9LzYl               23
#
#                                Playlist_id
# 0  spotify:playlist:2CXMVKT2IuLSeA4Rv7pMxD
# 1  spotify:playlist:2CXMVKT2IuLSeA4Rv7pMxD
# 2  spotify:playlist:2CXMVKT2IuLSeA4Rv7pMxD
# 3  spotify:playlist:2CXMVKT2IuLSeA4Rv7pMxD
# 4  spotify:playlist:2CXMVKT2IuLSeA4Rv7pMxD

# %%
# next we'll pull related artist data- skipping any null entries 
artist_info = []
for i in Playlist_tracks['artist_id']:
    if i != 'NULL':
        try:
            artists= sp.artist(i)
            artist_info.append(artists)
        except:
            pass

# %%
# create our artist lists 
artist_followers = []
artist_genres = []
artist_popularity = []
artist_name = []
artist_Id = []

for i, j in enumerate(artist_info):
    artist_name.append(j['name'])
    artist_followers.append(j['followers']['total'])
    artist_genres.append(j['genres'])
    artist_popularity.append(j['popularity'])
    artist_Id.append(j['id'])

# %%
# create an artist dataframe

'''
artist_name(str): artist name
artist_id(str): unique identifer of artists 
artist_followers(int): total number of followes each artist has
artist_genre(str): if applicable, description of artist genre
artist_popularity(int):  a popularity score spotify assigns to each artist
'''

artists = pd.DataFrame({'artist_name':artist_name,'artist_id':artist_Id,'artist_followers':artist_followers,'artist_genre':artist_genres,
                       'artist_popularity':artist_popularity})

# %%
artists['artist_genre']
# Out:
# 0                                                      []
# 1                                                      []
# 2                                         [seattle indie]
# 3                                                      []
# 4                                                      []
#                               ...
# 5078    [dance pop, electropop, modern rock, pop, pop ...
# 5079                                 [pop, post-teen pop]
# 5080                    [alternative r&b, indie r&b, pop]
# 5081                                                [pop]
# 5082    [dance pop, edm, electropop, pop, pop edm, pos...
# Name: artist_genre, Length: 5083, dtype: object

# %% [markdown]
# #### Let's clean up these dataframes before we migrate them into a db

# %%
Playlist_tracks.drop(Playlist_tracks.loc[Playlist_tracks['track_name']== 'NULL'].index,inplace=True)

# %%
# let's update the track numbers removing Null values
track_update = Playlist_tracks['Playlist_id'].value_counts().rename_axis('Playlist_uri').reset_index(name='total_tracks_update')
track_update
# track_update.columns =['Playlist_uri', 'total_tracks_update']
# track_update
# Out:
#                                Playlist_uri  total_tracks_update
# 0   spotify:playlist:0DMxXTG4lkkDFEnZ9kf0ee                  545
# 40                                  Afropop  37i9dQZF1DWYs2pvwxWA7l
# 41                        Comedy Top Tracks  37i9dQZF1DWSRoT7QRAibZ
# 42                         Metal Essentials  37i9dQZF1DWWOaP4H0w5b0
# 43                       Reggaeton Classics  37i9dQZF1DX8SfyqmSFDwe
# 44                           Blues Classics  37i9dQZF1DXd9rSDyQguIk
# 45                               Funky Jams  37i9dQZF1DX6drTZKzZwSo
# 46                          Travel Songs 💫🌎  0yXe2Ok6uWm15lzStDZIyN
#
#                                  Playlist_description  Total_tracks  \
# 0   Weekly toplist of Music Authentic, a different...            16
# 1   New music from Travis Scott, Polo G and A$AP F...            50
# 2   Start your sangeet night party with this Playl...            31
# 3   The hits of tomorrow are on Spotify today. Cov...            88
# 4   This country playlist celebrates the best in c...            35
# 5                Pop hits to keep your workout fresh.           100
# 6   Rock legends and epic songs that continue to i...           145
# 7                   Sing along and enjoy the drive...           100
# 8   These hits were made to stay! Revive los éxito...           100
# 9     Get happy with today's dose of feel-good songs!            78
# 10                                                               83
# 11  In celebration of #BlackHistoryMonth, we've co...            32
# 12                                  Music to game to.           200
# 13               Uptempto instrumental hip-hop beats.           143
# 14                                                               50
# 15  Kick back to the best new and recent chill tunes.           130
# 16                                                               76
# 17                                                               50
# 18        Inspiring and relaxing music for your walk.            54
# 19    Click shuffle to send you on a trip to the past           278
# 20                                                              236
# 21  The best alternative songs of the decade so fa...            80
# 22  The revolutionaries, the allies, and the just ...            61
# 23  The right music can make a good tailgate great...           116
# 24      Gentle ambient piano to help you fall asleep.           270
# 25  A selection of the greatest classical tunes; t...           172
# 26  Chill instrumental beats. Cover / Artwork: Tri...           292
# 27  Explore the ever-evolving indie folk and roots...           100
# 28  A collection of the hottest soul tracks from t...            40
# 29  Celebrate legendary DJ/BBC Radio 1 host John P...            60
# 30  Dinner with Friends? Here's the perfect playlist.           100
# 31  ¡Ponte cursi con las canciones más románticas ...            60
# 32  Score all the hottest hits from your favourite...            50
# 33  Punk rock from the 90s and 00s that you need i...            50
# 34  The new school of Regional Mexican. Los nuevos...            75
# 35  Featuing talented artists that know how to pop...            14
# 36                             Best Songs to Dance on            62
# 37           Desi hits from South Asia and the world.            75
# 38  Best Anime OST, Songs, Music Opening &amp; End...           111
# 39  MISSING SONGS: Fanfare by Thomas Gold; REMIXES...           545
# 40  The biggest Afropop records on the planet.  Co...            50
# 41  Get to know some of the most loved comedians o...           102
# 42  Want some metal? Better to start with the esse...            78
# 43  Solo los clásicos. The movement’s roots. Cover...           100
# 44                   Nothing but classic blues tracks            70
# 45                                      Classic funk.            55
# 46                                                              233
#
#                                Playlist_uri
# 0   spotify:playlist:2CXMVKT2IuLSeA4Rv7pMxD
# 1   spotify:playlist:37i9dQZF1DX0XUsuxWHRQd
# 2   spotify:playlist:37i9dQZF1DX2ktNbDFDPWZ
# 3   spotify:playlist:37i9dQZF1DWUa8ZRTfalHk
# 4   spotify:playlist:6nU0t33tQA2i0qTI5HiyRV
# 5   spotify:playlist:37i9dQZF1DX70RN3TfWWJh
# 6   spotify:playlist:37i9dQZF1DWXRqgorJj26U
# 7   spotify:playlist:37i9dQZF1DWWMOmoXKqHTD
# 8   spotify:playlist:37i9dQZF1DXbLMw3ry7d7k
# 9   spotify:playlist:37i9dQZF1DX3rxVfibe1L0
# 10  spotify:playlist:2KFz8HGQ2NpaC6uYFTq4Sg
# 11  spotify:playlist:4WqKz9qNKwICVYSfZsQ4gq
# 12  spotify:playlist:37i9dQZF1DX9QWEVCu9UDA
# 13  spotify:playlist:37i9dQZF1DWZZbwlv3Vmtr
# 14  spotify:playlist:7jCvrseBwisIEfYOWFS5Vd
# 15  spotify:playlist:37i9dQZF1DX4WYpdgoIcn6
# 16  spotify:playlist:4DjPDmk3r4OUwwzJTafBFJ
# 17  spotify:playlist:6u1Ura1PXLSyavFsnaIiXP
# 18  spotify:playlist:37i9dQZF1DX5yf1SQXKtUJ
# 19  spotify:playlist:4RvFgqkdx11Yeke2Wc3bEc
# 20  spotify:playlist:7npwN08ckIXYrMyRzfUe2L
# 21  spotify:playlist:37i9dQZF1DX873GaRGUmPl
# 22  spotify:playlist:37i9dQZF1DX59HcpGmPXYR
# 23  spotify:playlist:37i9dQZF1DXdgnLr18vPvu
# 24  spotify:playlist:37i9dQZF1DWZd79rJ6a7lp
# 25  spotify:playlist:37i9dQZF1DWWEJlAGA9gs0
# 26  spotify:playlist:37i9dQZF1DX0SM0LYsmbMT
# 27  spotify:playlist:37i9dQZF1DWYV7OOaGhoH0
# 28  spotify:playlist:37i9dQZF1DWULEW2RfoSCi
# 29  spotify:playlist:37i9dQZF1DWY3pbjsJ6MxA
# 30  spotify:playlist:37i9dQZF1DX4xuWVBs4FgJ
# 31  spotify:playlist:37i9dQZF1DX1S3aM8sZo63
# 32  spotify:playlist:37i9dQZF1DX9tPFwDMOaN1
# 33  spotify:playlist:37i9dQZF1DXd6tJtr4qeot
# 34  spotify:playlist:37i9dQZF1DX10A9MXc7csF
# 35  spotify:playlist:6yAd7B2Vrw5kJtfqpuPbtf
# 36  spotify:playlist:0sjIXTb8OgGBi1lEu0UGRC
# 37  spotify:playlist:37i9dQZF1DWTwzVdyRpXm1
# 38  spotify:playlist:1YA5cPIfDy3L03bGnNiDM7
# 39  spotify:playlist:0DMxXTG4lkkDFEnZ9kf0ee
# 40  spotify:playlist:37i9dQZF1DWYs2pvwxWA7l
# 41  spotify:playlist:37i9dQZF1DWSRoT7QRAibZ
# 42  spotify:playlist:37i9dQZF1DWWOaP4H0w5b0
# 43  spotify:playlist:37i9dQZF1DX8SfyqmSFDwe
# 44  spotify:playlist:37i9dQZF1DXd9rSDyQguIk
# 45  spotify:playlist:37i9dQZF1DX6drTZKzZwSo
# 46  spotify:playlist:0yXe2Ok6uWm15lzStDZIyN

# %%
top_playlists = pd.merge(top_playlists, track_update, on='Playlist_uri', how='left' )

# %%
top_playlists = top_playlists.drop('Total_tracks', axis=1)
top_playlists
# Out:
#                               Playlist_name             Playlist_id  \
# 0                   Music Authentic Toplist  2CXMVKT2IuLSeA4Rv7pMxD
# 1                                 RapCaviar  37i9dQZF1DX0XUsuxWHRQd
# 2                             Sangeet Night  37i9dQZF1DX2ktNbDFDPWZ
#                                  Playlist_description  \
# 0   Weekly toplist of Music Authentic, a different...
# 1   New music from Travis Scott, Polo G and A$AP F...
# 2   Start your sangeet night party with this Playl...
# 3   The hits of tomorrow are on Spotify today. Cov...
# 4   This country playlist celebrates the best in c...
# 5                Pop hits to keep your workout fresh.
# 6   Rock legends and epic songs that continue to i...
# 7                   Sing along and enjoy the drive...
# 8   These hits were made to stay! Revive los éxito...
# 9     Get happy with today's dose of feel-good songs!
# 10
# 11  In celebration of #BlackHistoryMonth, we've co...
# 12                                  Music to game to.
# 13               Uptempto instrumental hip-hop beats.
# 14
# 15  Kick back to the best new and recent chill tunes.
# 16
# 17
# 18        Inspiring and relaxing music for your walk.
# 19    Click shuffle to send you on a trip to the past
# 20
# 21  The best alternative songs of the decade so fa...
# 22  The revolutionaries, the allies, and the just ...
# 23  The right music can make a good tailgate great...
# 24      Gentle ambient piano to help you fall asleep.
# 25  A selection of the greatest classical tunes; t...
# 26  Chill instrumental beats. Cover / Artwork: Tri...
# 27  Explore the ever-evolving indie folk and roots...
# 28  A collection of the hottest soul tracks from t...
# 29  Celebrate legendary DJ/BBC Radio 1 host John P...
# 30  Dinner with Friends? Here's the perfect playlist.
# 31  ¡Ponte cursi con las canciones más románticas ...
# 32  Score all the hottest hits from your favourite...
# 33  Punk rock from the 90s and 00s that you need i...
# 34  The new school of Regional Mexican. Los nuevos...
# 35  Featuing talented artists that know how to pop...
# 36                             Best Songs to Dance on
# 37           Desi hits from South Asia and the world.
# 38  Best Anime OST, Songs, Music Opening &amp; End...
# 39  MISSING SONGS: Fanfare by Thomas Gold; REMIXES...
# 40  The biggest Afropop records on the planet.  Co...
# 41  Get to know some of the most loved comedians o...
# 42  Want some metal? Better to start with the esse...
# 43  Solo los clásicos. The movement’s roots. Cover...
# 44                   Nothing but classic blues tracks
# 45                                      Classic funk.
# 46
#
#                                Playlist_uri  total_tracks_update
# 0   spotify:playlist:2CXMVKT2IuLSeA4Rv7pMxD                   16
# 1   spotify:playlist:37i9dQZF1DX0XUsuxWHRQd                   50
# 2   spotify:playlist:37i9dQZF1DX2ktNbDFDPWZ                   31
# 3   spotify:playlist:37i9dQZF1DWUa8ZRTfalHk                   88
# 4   spotify:playlist:6nU0t33tQA2i0qTI5HiyRV                   35
# 5   spotify:playlist:37i9dQZF1DX70RN3TfWWJh                  100
# 6   spotify:playlist:37i9dQZF1DWXRqgorJj26U                  145
# 7   spotify:playlist:37i9dQZF1DWWMOmoXKqHTD                  100
# 8   spotify:playlist:37i9dQZF1DXbLMw3ry7d7k                  100
# 9   spotify:playlist:37i9dQZF1DX3rxVfibe1L0                   78
# 10  spotify:playlist:2KFz8HGQ2NpaC6uYFTq4Sg                   83
# 11  spotify:playlist:4WqKz9qNKwICVYSfZsQ4gq                   32
# 12  spotify:playlist:37i9dQZF1DX9QWEVCu9UDA                  200
# 13  spotify:playlist:37i9dQZF1DWZZbwlv3Vmtr                  143
# 14  spotify:playlist:7jCvrseBwisIEfYOWFS5Vd                   50
# 15  spotify:playlist:37i9dQZF1DX4WYpdgoIcn6                  130
# 16  spotify:playlist:4DjPDmk3r4OUwwzJTafBFJ                   76
# 17  spotify:playlist:6u1Ura1PXLSyavFsnaIiXP                   50
# 18  spotify:playlist:37i9dQZF1DX5yf1SQXKtUJ                   54
# 19  spotify:playlist:4RvFgqkdx11Yeke2Wc3bEc                  278
# 20  spotify:playlist:7npwN08ckIXYrMyRzfUe2L                  236
# 21  spotify:playlist:37i9dQZF1DX873GaRGUmPl                   80
# 22  spotify:playlist:37i9dQZF1DX59HcpGmPXYR                   61
# 23  spotify:playlist:37i9dQZF1DXdgnLr18vPvu                  116
# 24  spotify:playlist:37i9dQZF1DWZd79rJ6a7lp                  270
# 25  spotify:playlist:37i9dQZF1DWWEJlAGA9gs0                  172
# 26  spotify:playlist:37i9dQZF1DX0SM0LYsmbMT                  292
# 27  spotify:playlist:37i9dQZF1DWYV7OOaGhoH0                  100
# 28  spotify:playlist:37i9dQZF1DWULEW2RfoSCi                   40
# 29  spotify:playlist:37i9dQZF1DWY3pbjsJ6MxA                   60
# 30  spotify:playlist:37i9dQZF1DX4xuWVBs4FgJ                  100
# 31  spotify:playlist:37i9dQZF1DX1S3aM8sZo63                   60
# 32  spotify:playlist:37i9dQZF1DX9tPFwDMOaN1                   50
# 33  spotify:playlist:37i9dQZF1DXd6tJtr4qeot                   50
# 34  spotify:playlist:37i9dQZF1DX10A9MXc7csF                   75
# 35  spotify:playlist:6yAd7B2Vrw5kJtfqpuPbtf                   14
# 36  spotify:playlist:0sjIXTb8OgGBi1lEu0UGRC                   62
# 37  spotify:playlist:37i9dQZF1DWTwzVdyRpXm1                   75
# 38  spotify:playlist:1YA5cPIfDy3L03bGnNiDM7                  111
# 39  spotify:playlist:0DMxXTG4lkkDFEnZ9kf0ee                  545
# 40  spotify:playlist:37i9dQZF1DWYs2pvwxWA7l                   50
# 41  spotify:playlist:37i9dQZF1DWSRoT7QRAibZ                  102
# 42  spotify:playlist:37i9dQZF1DWWOaP4H0w5b0                   78
# 43  spotify:playlist:37i9dQZF1DX8SfyqmSFDwe                  100
# 44  spotify:playlist:37i9dQZF1DXd9rSDyQguIk                   70
# 45  spotify:playlist:37i9dQZF1DX6drTZKzZwSo                   55
# 46  spotify:playlist:0yXe2Ok6uWm15lzStDZIyN                  231

# %%
# remove brackets from genre 
artists['artist_genre'] = artists['artist_genre'].astype(str)

# %%
artists['artist_genre'] =artists['artist_genre'].str.replace(']','')

# %%
artists['artist_genre']= artists['artist_genre'].str.replace('[','')

# %%
artists['artist_genre']
# Out:
# 0
# 1
# 2                                         'seattle indie'
# 3
# 4
#                               ...
# 5078    'dance pop', 'electropop', 'modern rock', 'pop...
# 5079                               'pop', 'post-teen pop'
# 5080                'alternative r&b', 'indie r&b', 'pop'
# 5081                                                'pop'
# 5082    'dance pop', 'edm', 'electropop', 'pop', 'pop ...
# Name: artist_genre, Length: 5083, dtype: object

# %%
import sqlite3

# %%
con = sqlite3.connect('Spotify_playlists.db')

# %%
top_playlists.to_sql('top_playlists',con,if_exists='replace',index=True)

# %%
Playlist_tracks.to_sql('playlist_tracks',con, if_exists='replace',index=True)

# %%
artists.to_sql('artists',con, if_exists='replace',index=True)

# %%
con.close()
